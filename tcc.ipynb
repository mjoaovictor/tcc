# %% [markdown]
# # Stroke Prediction
#
# Referência: _https://www.kaggle.com/code/tumpanjawat/stroke-prediction-eda-resampling-xgboost/notebook_

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# set global seaborn style
sns.set_theme(style="whitegrid", palette="muted", font_scale=1)
